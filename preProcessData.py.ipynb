# %%
import csv
import pandas as pd
import numpy as np
import math

# %%
def loadCSV(fileName):
    data_frame = pd.read_csv(fileName)
    mapping = {'usual':1, 'pretentious': 2, 'great_pret': 3}
    data_frame.replace({'usual': mapping, 'pretentious': mapping, 'great_pret': mapping})
    data = np.asarray(data_frame)
#    np.random.shuffle(data)
    return data

# %%
if __name__ == "__main__":
    fileName = "nursery.data.txt"
    data = loadCSV(fileName)
    print data[0]
    
    df = pd.read_csv(fileName)
    mapping = {'usual':1, 'great_pret':2}
    df.replace({'usual': mapping, 'great_pret': mapping})
    print df
# Out:
# ['usual' 'proper' 'complete' '1' 'convenient' 'convenient' 'nonprob'
#  'priority' 'priority']
#             usual     proper  complete     1  convenient convenient.1  \
# 0           usual     proper  complete     1  convenient   convenient
# 1           usual     proper  complete     1  convenient   convenient
# 2           usual     proper  complete     1  convenient   convenient
# 3           usual     proper  complete     1  convenient   convenient
# 4           usual     proper  complete     1  convenient   convenient
# 5           usual     proper  complete     1  convenient   convenient
# 6           usual     proper  complete     1  convenient   convenient
# 7           usual     proper  complete     1  convenient   convenient
# 8           usual     proper  complete     1  convenient       inconv
# 9           usual     proper  complete     1  convenient       inconv
# 10          usual     proper  complete     1  convenient       inconv
# ...
